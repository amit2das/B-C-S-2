# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
! apt-get update -qq > /dev/null   
# Install java
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! pip install nlu pyspark==2.4.7
import nlu
# Out:
# debconf: delaying package configuration, since apt-utils is not installed
# Collecting nlu
#   Downloading nlu-1.1.4-py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 1.2 MB/s eta 0:00:01
# Collecting pyspark==2.4.7
#   Downloading pyspark-2.4.7.tar.gz (217.9 MB)
#      |████████████████████████████████| 217.9 MB 53 kB/s s eta 0:00:01    |███                             | 20.5 MB 22.1 MB/s eta 0:00:09     |██████████████████████          | 149.6 MB 72.1 MB/s eta 0:00:01
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 52.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from nlu) (1.2.2)
# Requirement already satisfied: pyarrow>=0.16.0 in /opt/conda/lib/python3.7/site-packages (from nlu) (3.0.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from nlu) (1.19.5)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from nlu) (0.6)
# Collecting spark-nlp<2.8,>=2.7.1
#   Downloading spark_nlp-2.7.5-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 42.3 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas->nlu) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->nlu) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->nlu) (1.15.0)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.7-py2.py3-none-any.whl size=218279465 sha256=914a68e51cb83dc4231ea3ace9362d3f8d613cb3d54825905fe1417be041b967
#   Stored in directory: /root/.cache/pip/wheels/da/28/74/56054e5fe3413c8c58b67e4d7483d4864fe483920c9b8ec754
# Successfully built pyspark
# Installing collected packages: spark-nlp, py4j, pyspark, nlu
# Successfully installed nlu-1.1.4 py4j-0.10.7 pyspark-2.4.7 spark-nlp-2.7.5

# %%
nlu.load('emotion').predict('wow that was easy')
# Out:
# classifierdl_use_emotion download started this may take some time.
# Approximate size to download 21.3 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
#                                             sentence_embeddings   emotion  \
# origin_index
# 0             [-0.01886986754834652, 0.028681324794888496, 0...  surprise
#
#                        sentence emotion_confidence
# origin_index
# 0             wow that was easy           0.999585

# %%
data = pd.read_csv("../input/scopus-5/ABCDD.csv")
df = data[['Abstract']]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df['Abstract'] = df['Abstract'].str.replace('[^a-zA-Z]',' ').str.lower()

# %%
stop_re = '\\b'+'\\b|\\b'.join(nltk.corpus.stopwords.words('english'))+'\\b'

# %%
df['Abstract'] = df['Abstract'].str.replace(stop_re, '')

# %%
df['Abstract'].head()
# Out:
# 0    several fundamental problems  arise  optimizat...
# 1    electronic voltage transformer   electricity p...
# 2    various methods  machine learning   implemente...
# 3      study   propose  model  consciousness    imp...
# 4    examination performance    measure  competence...
# Name: Abstract, dtype: object

# %%
pipe = nlu.load('embed_sentence.bert')
predictions = pipe.predict(df.Abstract, output_level='document')
predictions
# Out:
# sent_small_bert_L2_128 download started this may take some time.
# Approximate size to download 16.1 MB
# [OK!]
#                                  embed_sentence_bert_embeddings  \
# origin_index
# 0             [-0.30958321690559387, 0.32803720235824585, -0...
# 1             [0.029165567830204964, 0.8990737795829773, -0....
# 2             [-0.48946917057037354, 0.8942908644676208, -0....
# 3             [-0.1395428478717804, 0.46414247155189514, -0....
# 4             [-0.7468781471252441, 1.0565576553344727, -0.3...
# 5             [-0.43900567293167114, 1.5381633043289185, -0....
# 6             [-0.6192795634269714, 1.1968283653259277, -0.8...
# 7             [-0.1351013481616974, 0.9480631351470947, -0.4...
# 8             [-0.15662378072738647, 1.1727793216705322, -0....
# 9             [-0.11728588491678238, 0.8513278365135193, -0....
# 10            [-1.593714952468872, 1.2038428783416748, -1.97...
# 11            [-0.2878391742706299, 0.7004147171974182, -0.3...
# 12            [-0.24506044387817383, 0.7661380767822266, -0....
# 13            [-0.328654021024704, 0.8969658017158508, -0.20...
# 14            [-0.20236769318580627, 1.0497113466262817, -0....
# 15            [-0.2967684864997864, 1.057940125465393, -0.47...
# 16            [-0.31152307987213135, 0.8619762659072876, -0....
# 17            [-0.2760927677154541, 0.7875632047653198, -0.6...
# 18            [0.35926491022109985, 1.10565185546875, -0.786...
# 19            [-0.0698508769273758, 1.4012702703475952, -0.5...
# 20            [-0.4983993470668793, 0.36242398619651794, -0....
# 21            [-0.9760749936103821, 0.2942976951599121, -0.3...
# 22            [-0.20973394811153412, 1.2868403196334839, -0....
# 23            [-0.4558517038822174, 1.2485957145690918, -0.4...
# 24            [-0.12919898331165314, 0.506885826587677, -0.4...
# 25            [-0.2669939696788788, 0.8092978000640869, 0.02...
# 26            [-0.29463842511177063, 1.2081953287124634, -0....
# 27            [-0.4167158007621765, 0.8048627376556396, -0.7...
# 28            [-0.10355936735868454, 0.47551611065864563, -0...
#
#                                                        document  \
# origin_index
# 0             several fundamental problems arise optimizatio...
# 1             electronic voltage transformer electricity par...
# 2             various methods machine learning implemented m...
# 3             study propose model consciousness implemented ...
# 4             examination performance measure competence exi...
# 5             paper discusses risk assessment changed artifi...
# 6             study big data machine learning offers signifi...
# 7             artificial intelligence finding way ever appli...
# 8             advent incorporation technology businesses ref...
# 9             artificial intelligence ai refers field comput...
# 10
# 11            artificial intelligence ai technologies become...
# 12            machine learning systems become democratized b...
# 13            recent years machine learning ml systems deplo...
# 14            machine learning models play important role de...
# 15            application ai finance increasingly dependent ...
# 16            machine learning community become alert ways p...
# 17            new ai system developed optimize vaccination s...
# 18            excessive demand mobile wireless usage ieee ax...
# 19            ai powerful capabilities prediction automation...
# 20            virtue ethics seems promising moral theory und...
# 21            shown important criterion human happiness long...
# 22            numerous challenges designing algorithms inter...
# 23            confidentiality patient information legislated...
# 24            advancements ai field unfold tremendous opport...
# 25            article presents first systematic analysis eth...
# 26            aim responsible robotics initiative ensure res...
# 27            artificial intelligence ai based robots become...
# 28            framework fundamental hence broad notion ident...
#
#                                                        Abstract  \
# origin_index
# 0             several fundamental problems  arise  optimizat...
# 1             electronic voltage transformer   electricity p...
# 2             various methods  machine learning   implemente...
# 3               study   propose  model  consciousness    imp...
# 4             examination performance    measure  competence...
# 5              paper discusses  risk assessment  changed  ar...
# 6              study  big data  machine learning offers sign...
# 7             artificial intelligence  finding  way  ever  a...
# 8              advent  incorporation  technology  businesses...
# 9             artificial intelligence  ai  refers   field  c...
# 10
# 11             artificial intelligence  ai  technologies bec...
# 12             machine learning systems become democratized ...
# 13             recent years machine learning  ml  systems   ...
# 14            machine learning models play  important role  ...
# 15             application  ai  finance  increasingly depend...
# 16             machine learning community  become alert   wa...
# 17             new ai system   developed  optimize vaccinati...
# 18              excessive demand   mobile  wireless usage  i...
# 19            ai  powerful capabilities  prediction  automat...
# 20            virtue ethics seems    promising moral theory ...
# 21               shown   important criterion  human happines...
# 22              numerous challenges  designing algorithms  i...
# 23             confidentiality  patient information  legisla...
# 24            advancements   ai field unfold tremendous oppo...
# 25             article presents  first  systematic analysis ...
# 26              aim   responsible robotics initiative   ensu...
# 27            artificial intelligence  ai  based robots  bec...
# 28               framework   fundamental  hence broad  notio...
#
#                                                            text
# origin_index
# 0             several fundamental problems  arise  optimizat...
# 1             electronic voltage transformer   electricity p...
# 2             various methods  machine learning   implemente...
# 3               study   propose  model  consciousness    imp...
# 4             examination performance    measure  competence...
# 5              paper discusses  risk assessment  changed  ar...
# 6              study  big data  machine learning offers sign...
# 7             artificial intelligence  finding  way  ever  a...
# 8              advent  incorporation  technology  businesses...
# 9             artificial intelligence  ai  refers   field  c...
# 10
# 11             artificial intelligence  ai  technologies bec...
# 12             machine learning systems become democratized ...
# 13             recent years machine learning  ml  systems   ...
# 14            machine learning models play  important role  ...
# 15             application  ai  finance  increasingly depend...
# 16             machine learning community  become alert   wa...
# 17             new ai system   developed  optimize vaccinati...
# 18              excessive demand   mobile  wireless usage  i...
# 19            ai  powerful capabilities  prediction  automat...
# 20            virtue ethics seems    promising moral theory ...
# 21               shown   important criterion  human happines...
# 22              numerous challenges  designing algorithms  i...
# 23             confidentiality  patient information  legisla...
# 24            advancements   ai field unfold tremendous oppo...
# 25             article presents  first  systematic analysis ...
# 26              aim   responsible robotics initiative   ensu...
# 27            artificial intelligence  ai  based robots  bec...
# 28               framework   fundamental  hence broad  notio...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# put all sentence embeddings in a matrix
e_col = 'embed_sentence_bert_embeddings'

def get_sim_df_for_iloc (sent_iloc, predictions=predictions, e_col= e_col, pipe= pipe):
    
    embed_mat = np.array([x for x in predictions[e_col]])
# calculate distance between every embedding pair
    sim_mat = cosine_similarity(embed_mat,embed_mat)
#get sim score for a given sentence at position df.iloc[sentence_id]
    print("Similarities for Sentence : " + df.iloc[sent_iloc].Abstract)
    df['sim_score'] = sim_mat[sent_iloc]
    return df

sentence_to_compare= 12
sim_df_for_one_sent = get_sim_df_for_iloc(sentence_to_compare, predictions, e_col)
sim_df_for_one_sent.sort_values('sim_score', ascending=False)

# write sim scores to df

#sim_df.sort_values('sim_score', ascending = False)
# Out:
# Similarities for Sentence :  machine learning systems become democratized   becomes increasingly important  help users easily debug  models  however  current data tools  still primitive   comes  helping users trace model performance problems   way   data   focus   particular problem  slicing data  identify subsets   validation data   model performs poorly     important problem  model validation   overall model performance  fail  reflect    smaller subsets   slicing allows users  analyze  model performance    granular level  unlike general techniques  e g   clustering    find arbitrary slices   goal   find interpretable slices    easier  take action compared  arbitrary subsets    problematic  large   propose mathsf slice finder slicefinder     interactive framework  identifying  slices using statistical techniques  applications include diagnosing model fairness  fraud detection   identifying slices   interpretable  humans  crucial   research  part   larger trend  big data  artificial intelligence  ai  integration  opens many opportunities  new research              ieee
#                                              Abstract  sim_score
# 12   machine learning systems become democratized ...   1.000000
# 13   recent years machine learning  ml  systems   ...   0.959530
# 8    advent  incorporation  technology  businesses...   0.939237
# 2   various methods  machine learning   implemente...   0.938906
# 7   artificial intelligence  finding  way  ever  a...   0.936523
# 16   machine learning community  become alert   wa...   0.932277
# 14  machine learning models play  important role  ...   0.931571
# 27  artificial intelligence  ai  based robots  bec...   0.930172
# 0   several fundamental problems  arise  optimizat...   0.923994
# 15   application  ai  finance  increasingly depend...   0.920368
# 6    study  big data  machine learning offers sign...   0.919822
# 23   confidentiality  patient information  legisla...   0.919000
# 9   artificial intelligence  ai  refers   field  c...   0.916294
# 22    numerous challenges  designing algorithms  i...   0.912913
# 18    excessive demand   mobile  wireless usage  i...   0.912527
# 17   new ai system   developed  optimize vaccinati...   0.907431
# 28     framework   fundamental  hence broad  notio...   0.901038
# 5    paper discusses  risk assessment  changed  ar...   0.900446
# 4   examination performance    measure  competence...   0.899353
# 24  advancements   ai field unfold tremendous oppo...   0.896285
# 1   electronic voltage transformer   electricity p...   0.888821
# 3     study   propose  model  consciousness    imp...   0.882961
# 11   artificial intelligence  ai  technologies bec...   0.870848
# 26    aim   responsible robotics initiative   ensu...   0.869899
# 25   article presents  first  systematic analysis ...   0.862213
# 21     shown   important criterion  human happines...   0.857465
# 19  ai  powerful capabilities  prediction  automat...   0.851913
# 20  virtue ethics seems    promising moral theory ...   0.844873
# 10                                                      0.484101
